# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Earthquakes.csv")
data
# Out:
#       Unnamed: 0        Date      Time  latitude  longitude  depth  mag  \
# 0              0  2014-03-17  05:11:34  -20.0030   -70.8741   17.0  6.2
# 1              1  2014-03-16  21:16:30  -19.9246   -70.6278   20.0  6.7
# 2              2  2014-03-15  23:51:30   -5.5660   -80.8790    9.8  6.3
# 3              3  2014-03-15  08:59:21  -14.0935   -76.2968   20.0  6.1
# 4              4  2014-03-13  17:06:50   33.6793   131.8197   79.0  6.3
# ...          ...         ...       ...       ...        ...    ...  ...
# 8308        8308  1900-01-31  19:22:00   48.0000   146.0000  450.0  7.5
# 8309        8309  1900-01-20  06:33:00   20.0000  -105.0000    0.0  7.3
# 8310        8310  1900-01-18  07:46:00   44.5000   148.5000   35.0  6.7
# 8311        8311  1900-01-11  09:07:00   -5.0000   148.0000    0.0  7.0
# 8312        8312  1900-01-05  19:00:00   -3.0000   102.0000    0.0  7.0
#
#      magType  nst         net                        id  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# Time            0
# latitude        0
# longitude       0
# depth           0
# mag             1
# magType        15
# nst           202
# net             0
# id              0
# updated         0
# place           9
# type            0
# dtype: int64

# %%
data["mag"].mean()
data["mag"].fillna(data["mag"].mean(),inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data["magType"] = encoder.fit_transform(data["magType"])
data["net"] = encoder.fit_transform(data["net"])

# %%
data["nst"].mean()
data["nst"].fillna(data["nst"].mean(),inplace=True)

data
# Out:
#       Unnamed: 0        Date      Time  latitude  longitude  depth  mag  \
# 0              0  2014-03-17  05:11:34  -20.0030   -70.8741   17.0  6.2
# 1              1  2014-03-16  21:16:30  -19.9246   -70.6278   20.0  6.7
# 2              2  2014-03-15  23:51:30   -5.5660   -80.8790    9.8  6.3
# 3              3  2014-03-15  08:59:21  -14.0935   -76.2968   20.0  6.1
# 4              4  2014-03-13  17:06:50   33.6793   131.8197   79.0  6.3
# ...          ...         ...       ...       ...        ...    ...  ...
# 8308        8308  1900-01-31  19:22:00   48.0000   146.0000  450.0  7.5
# 8309        8309  1900-01-20  06:33:00   20.0000  -105.0000    0.0  7.3
# 8310        8310  1900-01-18  07:46:00   44.5000   148.5000   35.0  6.7
# 8311        8311  1900-01-11  09:07:00   -5.0000   148.0000    0.0  7.0
# 8312        8312  1900-01-05  19:00:00   -3.0000   102.0000    0.0  7.0
#
#       magType         nst  net                        id  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# Time          0
# latitude      0
# longitude     0
# depth         0
# mag           0
# magType       0
# nst           0
# net           0
# id            0
# updated       0
# place         9
# type          0
# dtype: int64

# %%
data
# Out:
#       Unnamed: 0        Date      Time  latitude  longitude  depth  mag  \
# 0              0  2014-03-17  05:11:34  -20.0030   -70.8741   17.0  6.2
# 1              1  2014-03-16  21:16:30  -19.9246   -70.6278   20.0  6.7
# 2              2  2014-03-15  23:51:30   -5.5660   -80.8790    9.8  6.3
# 3              3  2014-03-15  08:59:21  -14.0935   -76.2968   20.0  6.1
# 4              4  2014-03-13  17:06:50   33.6793   131.8197   79.0  6.3
# ...          ...         ...       ...       ...        ...    ...  ...
# 8308        8308  1900-01-31  19:22:00   48.0000   146.0000  450.0  7.5
# 8309        8309  1900-01-20  06:33:00   20.0000  -105.0000    0.0  7.3
# 8310        8310  1900-01-18  07:46:00   44.5000   148.5000   35.0  6.7
# 8311        8311  1900-01-11  09:07:00   -5.0000   148.0000    0.0  7.0
# 8312        8312  1900-01-05  19:00:00   -3.0000   102.0000    0.0  7.0
#
#       magType         nst  net                        id  \
# ...

# %%
x= data.drop(["Date","Unnamed: 0","Time","mag","id","updated","place","type"],axis=1)
y= data["mag"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       latitude  longitude  depth  magType    nst  net
# 5900    59.699   -149.416   30.2        6   36.0    1
# 7145     4.165    126.521   35.0        9   59.0    1
# 620     -3.760    141.943   23.0       11  231.0    4
# 1544    -8.255    124.930   10.0        8  146.0    4
# 6555    -5.600    153.600   96.0       15    0.0    1
# ...        ...        ...    ...      ...    ...  ...
# 5734    39.045     21.757   20.3       15  142.0    1
# 5191   -53.607   -134.226   19.0        8  103.0    1
# 5390   -51.987    -74.331    1.7        8  209.0    1
# 860      1.271    122.091   30.0       14  365.0    4
# 7270   -20.297    -69.965   35.0        9   95.0    1
#
# [6650 rows x 6 columns]

# %%
x_test
# Out:
#       latitude  longitude  depth  magType         nst  net
# 2862  -18.7830   169.2960  214.2        8  421.000000    1
# 5368   52.3490   151.6160  649.5        8  337.000000    1
# 2306  -13.6010   166.9160   52.3        8  284.000000    1
# 33     18.4753   145.2041  511.0       14  245.151399    5
# 5219   23.0370   122.1170   12.2        8  226.000000    1
# ...        ...        ...    ...      ...         ...  ...
# 1817  -10.6700   161.3600   19.0        9  174.000000    1
# 6068  -39.6600   -75.5300    0.0       15    0.000000    1
# 4216   31.5810    82.2380   24.1        8  115.000000    1
# 4446   28.9250   140.7880  128.7        8  349.000000    1
# 4567  -13.9200   167.2800  200.3        8  247.000000    1
#
# [1663 rows x 6 columns]

# %%
y_train
# Out:
# 5900    6.1
# 7145    7.7
# 620     6.0
# 1544    6.4
# 6555    6.6
#        ...
# 5734    6.2
# 5191    6.3
# 5390    6.5
# 860     7.4
# 7270    7.2
# Name: mag, Length: 6650, dtype: float64

# %%
y_test
# Out:
# 2862    6.9
# 5368    7.3
# 2306    6.2
# 33      6.0
# 5219    7.0
#        ...
# 1817    6.3
# 6068    6.5
# 4216    6.0
# 4446    6.7
# 4567    6.7
# Name: mag, Length: 1663, dtype: float64

# %% [markdown]
# XGBRREGRESSOR

# %%
XGBR = XGBRegressor()
XGBR.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
from sklearn import metrics
train_data_prediction = XGBR.predict(x_train)

error_score = metrics.r2_score(y_train,train_data_prediction)
print(error_score)
# Out:
# 0.7679757862959657

# %%
test_data_prediction = model.predict(x_test)
error_score = metrics.r2_score(y_test,test_data_prediction)

print(error_score)
# Out:
# 0.30368490673873927

# %% [markdown]
# LİNEER_REGRESSOR

# %%
model2 = LinearRegression()
model2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_data_prediction = model2.predict(x_train)

# %%
error_score = metrics.r2_score(y_train,train_data_prediction)
print(error_score)
# Out:
# 0.07075534231364922

# %%
data.keys()
# Out:
# Index(['Unnamed: 0', 'Date', 'Time', 'latitude', 'longitude', 'depth', 'mag',
#        'magType', 'nst', 'net', 'id', 'updated', 'place', 'type'],
#       dtype='object')

# %% [markdown]
# gbr

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(n_estimators=200,max_depth=1,random_state = 42)
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=1, n_estimators=200, random_state=42)

# %%
train_data_prediction = gbr.predict(x_train)

# %%
error_score = metrics.r2_score(y_train,train_data_prediction)
print(error_score)
# Out:
# 0.23170552849478454

# %% [markdown]
# svr

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x_train, y_train)
# Out:
# SVR()

# %%
train_data_prediction = regressor.predict(x_train)
error_score = metrics.r2_score(y_train,train_data_prediction)
print(error_score)
# Out:
# 0.1846022722267473

# %% [markdown]
# DECİSSİONTREEREGRESSİON

# %%
from sklearn.tree import DecisionTreeRegressor 
regressor = DecisionTreeRegressor(random_state = 42)

regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
train_data_prediction = regressor.predict(x_train)
error_score = metrics.r2_score(y_train,train_data_prediction)
print(error_score)
# Out:
# 0.9997657328457958

# %% [markdown]
# LAST PREDİCTİON SYSTEM

# %%
#latitude	longitude	depth	magType	nst	net
latitude = input("enter the latitude-->")
longitude = input("enter the longitude-->")
depth = input("enter the depth-->")
magType = input("enter the magType -->")
nst = input("enter the nst --> ")
net = input("enter the net --->")

# %%
# -51.987	-74.331 	1.7 	8	209.0	1-->5390
input_data = (latitude,	longitude	,depth	,magType ,nst, net)
input_data_np_array = np.array(input_data)

input_data_reshape = input_data_np_array.reshape(1,-1)

prediction_DT = regressor.predict(input_data_reshape)
print(prediction_DT)
print(y[5390])
# Out:
# [6.5]
# 6.5
# c:\Users\Huawei D14\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print("decission_tree MAG prediction--->",prediction_DT)
# Out:
# decission_tree prediction---> [6.5]

# %%
# Out:
#       latitude  longitude  depth  magType    nst  net
# 5900    59.699   -149.416   30.2        6   36.0    1
# 7145     4.165    126.521   35.0        9   59.0    1
# 620     -3.760    141.943   23.0       11  231.0    4
# 1544    -8.255    124.930   10.0        8  146.0    4
# 6555    -5.600    153.600   96.0       15    0.0    1
# ...        ...        ...    ...      ...    ...  ...
# 5734    39.045     21.757   20.3       15  142.0    1
# 5191   -53.607   -134.226   19.0        8  103.0    1
# 5390   -51.987    -74.331    1.7        8  209.0    1
# 860      1.271    122.091   30.0       14  365.0    4
# 7270   -20.297    -69.965   35.0        9   95.0    1
#
# [6650 rows x 6 columns]
